# %%
# %run funciones.py
import pandas as pd
from funciones import *

# ============================== parametros del dataset ==============================
div_split = 36
INPUT_LENGTH, OUTPUT_LENGTH = 36, 1
SCALER = 'Robust'
CONV = False
name_dataset = "travel_time_series_2col.csv"

# leer dataset
cols = ['id_linkref', 'horas', 'minute', 'travel_time']
origin_dataset = pd.read_csv('../data/travel_time_series_2col.csv', sep=',', usecols=cols)
dataset = origin_dataset[cols]

# delimitar links (0, 82)
range_links = (14, 49)
if range_links != (0, 82):
    dataset =  dataset[(dataset['id_linkref']>= range_links[0]) & (dataset['id_linkref']<=range_links[1])]
    print(f"Data set delimitado con Links desde {range_links[0]} - {range_links[1]} => {len(dataset['id_linkref'].unique())} links")

# preparar dataset
data, scaler = cargar_dataset(dataset, div_split, (INPUT_LENGTH, OUTPUT_LENGTH), name_scaler=SCALER, conv=False)
# Out:
# Data set delimitado con Links desde 14 - 49 => 36 links

# %%
# extraer dataset escalado
x_tr_s, y_tr_s = data['x_tr_s'], data['y_tr_s']
x_vl_s, y_vl_s = data['x_vl_s'], data['y_vl_s']
x_ts_s, y_ts_s = data['x_ts_s'], data['y_ts_s']

x_tr_s.shape, x_vl_s.shape ,x_ts_s.shape
# Out:
# ((73655, 36, 4), (9143, 36, 4), (9215, 36, 4))

# %%
import json
import keras
import subprocess
import tensorflow as tf
from tensorflow.python.platform import build_info as build
from keras.optimizers import RMSprop, Adam
from keras.models import Sequential
from keras.layers import LSTM, CuDNNLSTM, Dense,BatchNormalization, Dropout, RepeatVector, TimeDistributed, ConvLSTM2D, Flatten, Reshape

print("Tensorflow".ljust(25) + f":{tf.__version__}")
print("Keras".ljust(25) + f":{keras.__version__}")
print("GPU Available".ljust(25) + f":{len(tf.config.experimental.list_physical_devices('GPU'))}")
print("Cuda Built".ljust(25) + f":{tf.test.is_built_with_cuda()}")
print("Cuda Version".ljust(25) + f":{build.build_info['cuda_version']}")
print("Cudnn Version".ljust(25) + f":{build.build_info['cudnn_version']}")
print("List Tensorflow GPUs".ljust(25) + f":{tf.config.list_physical_devices('GPU')}")
print("Name of GPU".ljust(25) + f":{subprocess.check_output('nvidia-smi --query-gpu=gpu_name --format=csv', shell=True).decode().splitlines()[1]}")
print("Numpy Version".ljust(25) + f":{np.__version__}")
print("Pandas Version".ljust(25) + f":{pd.__version__}")
#print("Matplotlib Version".ljust(25) + f":{matplotlib.__version__}")
#print("Seaborn Version".ljust(25) + f":{sns.__version__}")
# Out:
# Tensorflow               :2.10.0
# Keras                    :2.10.0
# GPU Available            :1
# Cuda Built               :True
# Cuda Version             :64_112
# Cudnn Version            :64_8
# List Tensorflow GPUs     :[PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Name of GPU              :NVIDIA GeForce MX110
# Numpy Version            :1.24.3
# Pandas Version           :2.0.1

# %%
# Ajustar parámetros para reproducibilidad del entrenamiento
tf.random.set_seed(123)
tf.config.experimental.enable_op_determinism()

# =============================== PARAMETROS DEL MODELO ===============================
INPUT_SHAPE = (x_tr_s.shape[1], x_tr_s.shape[2]) # dimensiones del input
N_UNITS = 128 # unidades del LSTM
name_opt = 'RMSprop-lr5e-5'
ACT = 'linear' # funcion de activacion
name_function_loss = 'rmse'

# opimizador
opt = RMSprop(learning_rate=5e-5)

# funcion de perdida
def rmse(y_true, y_pred): 
    return tf.math.sqrt(tf.math.reduce_mean(tf.square(y_pred-y_true)))

# %%
# ================================= MODELO 1 =================================
# n_modelo = 'LSTM1'
# modelo = Sequential()
# modelo.add(LSTM(N_UNITS, input_shape=INPUT_SHAPE, return_sequences = False))
# modelo.add(Dense(OUTPUT_LENGTH, activation=ACT))

# # Compilación
# modelo.compile(optimizer = opt, loss = rmse, metrics=['mse', 'mae'])

# %%
# ================================= MODELO 2 =================================
n_modelo = 'LSMT2'
modelo = Sequential()
modelo.add(BatchNormalization(name = 'batch_norm_0', input_shape = INPUT_SHAPE))
modelo.add(LSTM(name ='lstm_1', units = N_UNITS, return_sequences = True))
modelo.add(Dropout(0.15, name = 'dropout_1'))
modelo.add(BatchNormalization(name = 'batch_norm_1'))
modelo.add(LSTM(name ='lstm_2', units = N_UNITS, return_sequences = False))
modelo.add(Dropout(0.1, name = 'dropout_2'))
modelo.add(BatchNormalization(name = 'batch_norm_2'))
modelo.add(RepeatVector(1))
modelo.add(LSTM(name ='lstm_3', units = N_UNITS, return_sequences = True))
modelo.add(Dropout(0.15, name = 'dropout_3'))
modelo.add(BatchNormalization(name = 'batch_norm_3'))
modelo.add(LSTM(name ='lstm_4', units = N_UNITS, return_sequences = False))
modelo.add(Dense(units = OUTPUT_LENGTH, name = 'dense_1', activation = ACT))

# Compilación
modelo.compile(optimizer = opt, loss = rmse, metrics=['mse', 'mae'])

# %%
# parametros de entrenamiento
EPOCHS = 100
BATCH_SIZE = 256 

# Entrenamiento
historia = modelo.fit(
    x = x_tr_s,
    y = y_tr_s,
    batch_size = BATCH_SIZE,
    epochs = EPOCHS,
    validation_data = (x_vl_s, y_vl_s)
)

# GUARDAR MODELO
name_files = f"{n_modelo}_e{EPOCHS}b{BATCH_SIZE}_{SCALER}_in{INPUT_SHAPE[0]}-{INPUT_SHAPE[1]}_dt{range_links[0]}-{range_links[1]}"
modelo.save(f'../models/{name_files}.h5')
print('Entrenamiento finalizado y modelo guardado')
print('\nEVALUANDO MODELO')
# Cálculo de rmses para train, val y test
rmse_dict = {'train':modelo.evaluate(x=x_tr_s, y=y_tr_s, verbose=1), 
             'val':  modelo.evaluate(x=x_vl_s, y=y_vl_s, verbose=1), 
             'test': modelo.evaluate(x=x_ts_s, y=y_ts_s, verbose=1)}

# recolectar parametros
param_dataset = {
    'range_links': range_links,
    'div_split': div_split,
    'INPUT_LENGTH': INPUT_LENGTH,
    'OUTPUT_LENGTH': OUTPUT_LENGTH,
    'scaler': SCALER,
    'isCONV': CONV,
    'name_dataset': name_dataset
}

param_model ={
    'INPUT_SHAPE': INPUT_SHAPE,
    'n_unist-LSMT': N_UNITS,
    'name_optimizer': name_opt,
    'name_function_activation': ACT,
    'name_function_loss': name_function_loss, 
    'n_modelo': n_modelo,
    'epoch': EPOCHS,
    'BATCH_SIZE': BATCH_SIZE,
}

# GUARDAR DATOS DE ENTRENAMIENTO
hist_df = pd.DataFrame(historia.history)  
with open(f'../info_models/{name_files}.json', mode='w') as f:
    temp = {**hist_df.to_dict('list'), **rmse_dict, **param_dataset, **param_model}
    json.dump(temp, f)
    print('Historial y evalucacion correctamente guardados')
# Out:
# Epoch 1/100
# 288/288 [==============================] - 40s 101ms/step - loss: 0.7464 - mse: 0.5610 - mae: 0.5595 - val_loss: 0.8309 - val_mse: 0.6962 - val_mae: 0.5974
# Epoch 2/100
# 288/288 [==============================] - 29s 100ms/step - loss: 0.7221 - mse: 0.5245 - mae: 0.5436 - val_loss: 0.7308 - val_mse: 0.5386 - val_mae: 0.5460
# Epoch 3/100
# 288/288 [==============================] - 28s 97ms/step - loss: 0.7117 - mse: 0.5094 - mae: 0.5357 - val_loss: 0.7225 - val_mse: 0.5266 - val_mae: 0.5382
# Epoch 4/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.7026 - mse: 0.4973 - mae: 0.5289 - val_loss: 0.7138 - val_mse: 0.5141 - val_mae: 0.5342
# Epoch 5/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6972 - mse: 0.4892 - mae: 0.5246 - val_loss: 0.7130 - val_mse: 0.5135 - val_mae: 0.5304
# Epoch 6/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6925 - mse: 0.4828 - mae: 0.5210 - val_loss: 0.7051 - val_mse: 0.5020 - val_mae: 0.5255
# Epoch 7/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6853 - mse: 0.4727 - mae: 0.5158 - val_loss: 0.7029 - val_mse: 0.4991 - val_mae: 0.5246
# Epoch 8/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6786 - mse: 0.4638 - mae: 0.5117 - val_loss: 0.6890 - val_mse: 0.4796 - val_mae: 0.5142
# Epoch 9/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6744 - mse: 0.4581 - mae: 0.5086 - val_loss: 0.6861 - val_mse: 0.4755 - val_mae: 0.5126
# Epoch 10/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6689 - mse: 0.4508 - mae: 0.5053 - val_loss: 0.6800 - val_mse: 0.4668 - val_mae: 0.5102
# Epoch 11/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6651 - mse: 0.4454 - mae: 0.5024 - val_loss: 0.6731 - val_mse: 0.4575 - val_mae: 0.5051
# Epoch 12/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6609 - mse: 0.4397 - mae: 0.4996 - val_loss: 0.6699 - val_mse: 0.4532 - val_mae: 0.5021
# Epoch 13/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6575 - mse: 0.4352 - mae: 0.4972 - val_loss: 0.6668 - val_mse: 0.4488 - val_mae: 0.5015
# Epoch 14/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6540 - mse: 0.4306 - mae: 0.4953 - val_loss: 0.6610 - val_mse: 0.4411 - val_mae: 0.4960
# Epoch 15/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6503 - mse: 0.4261 - mae: 0.4930 - val_loss: 0.6585 - val_mse: 0.4379 - val_mae: 0.4943
# Epoch 16/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6460 - mse: 0.4206 - mae: 0.4900 - val_loss: 0.6550 - val_mse: 0.4332 - val_mae: 0.4927
# Epoch 17/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6429 - mse: 0.4166 - mae: 0.4876 - val_loss: 0.6524 - val_mse: 0.4298 - val_mae: 0.4894
# Epoch 18/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6399 - mse: 0.4127 - mae: 0.4855 - val_loss: 0.6440 - val_mse: 0.4187 - val_mae: 0.4857
# Epoch 19/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6372 - mse: 0.4091 - mae: 0.4839 - val_loss: 0.6413 - val_mse: 0.4151 - val_mae: 0.4836
# Epoch 20/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6337 - mse: 0.4045 - mae: 0.4809 - val_loss: 0.6375 - val_mse: 0.4102 - val_mae: 0.4806
# Epoch 21/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6324 - mse: 0.4028 - mae: 0.4798 - val_loss: 0.6386 - val_mse: 0.4118 - val_mae: 0.4819
# Epoch 22/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6317 - mse: 0.4018 - mae: 0.4791 - val_loss: 0.6357 - val_mse: 0.4080 - val_mae: 0.4794
# Epoch 23/100
# 288/288 [==============================] - 32s 110ms/step - loss: 0.6294 - mse: 0.3991 - mae: 0.4778 - val_loss: 0.6358 - val_mse: 0.4080 - val_mae: 0.4795
# Epoch 24/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6283 - mse: 0.3979 - mae: 0.4769 - val_loss: 0.6331 - val_mse: 0.4044 - val_mae: 0.4781
# Epoch 25/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6276 - mse: 0.3970 - mae: 0.4766 - val_loss: 0.6367 - val_mse: 0.4091 - val_mae: 0.4804
# Epoch 26/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6270 - mse: 0.3959 - mae: 0.4759 - val_loss: 0.6315 - val_mse: 0.4025 - val_mae: 0.4760
# Epoch 27/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6255 - mse: 0.3941 - mae: 0.4746 - val_loss: 0.6316 - val_mse: 0.4026 - val_mae: 0.4764
# Epoch 28/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6235 - mse: 0.3918 - mae: 0.4736 - val_loss: 0.6310 - val_mse: 0.4017 - val_mae: 0.4785
# Epoch 29/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6239 - mse: 0.3920 - mae: 0.4736 - val_loss: 0.6315 - val_mse: 0.4022 - val_mae: 0.4784
# Epoch 30/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6229 - mse: 0.3909 - mae: 0.4727 - val_loss: 0.6316 - val_mse: 0.4025 - val_mae: 0.4774
# Epoch 31/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6219 - mse: 0.3903 - mae: 0.4730 - val_loss: 0.6316 - val_mse: 0.4025 - val_mae: 0.4762
# Epoch 32/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6217 - mse: 0.3893 - mae: 0.4720 - val_loss: 0.6295 - val_mse: 0.3998 - val_mae: 0.4746
# Epoch 33/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6212 - mse: 0.3889 - mae: 0.4720 - val_loss: 0.6310 - val_mse: 0.4018 - val_mae: 0.4752
# Epoch 34/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6204 - mse: 0.3880 - mae: 0.4714 - val_loss: 0.6295 - val_mse: 0.3997 - val_mae: 0.4765
# Epoch 35/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6202 - mse: 0.3872 - mae: 0.4709 - val_loss: 0.6282 - val_mse: 0.3983 - val_mae: 0.4733
# Epoch 36/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6189 - mse: 0.3857 - mae: 0.4701 - val_loss: 0.6316 - val_mse: 0.4024 - val_mae: 0.4738
# Epoch 37/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6181 - mse: 0.3851 - mae: 0.4696 - val_loss: 0.6276 - val_mse: 0.3976 - val_mae: 0.4712
# Epoch 38/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6183 - mse: 0.3857 - mae: 0.4696 - val_loss: 0.6280 - val_mse: 0.3977 - val_mae: 0.4739
# Epoch 39/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6182 - mse: 0.3850 - mae: 0.4697 - val_loss: 0.6276 - val_mse: 0.3973 - val_mae: 0.4734
# Epoch 40/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6181 - mse: 0.3852 - mae: 0.4698 - val_loss: 0.6254 - val_mse: 0.3945 - val_mae: 0.4733
# Epoch 41/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6175 - mse: 0.3840 - mae: 0.4694 - val_loss: 0.6263 - val_mse: 0.3956 - val_mae: 0.4729
# Epoch 42/100
# 288/288 [==============================] - 32s 110ms/step - loss: 0.6160 - mse: 0.3827 - mae: 0.4685 - val_loss: 0.6272 - val_mse: 0.3969 - val_mae: 0.4721
# Epoch 43/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6167 - mse: 0.3833 - mae: 0.4683 - val_loss: 0.6258 - val_mse: 0.3950 - val_mae: 0.4717
# Epoch 44/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6159 - mse: 0.3826 - mae: 0.4681 - val_loss: 0.6242 - val_mse: 0.3930 - val_mae: 0.4712
# Epoch 45/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6154 - mse: 0.3814 - mae: 0.4672 - val_loss: 0.6254 - val_mse: 0.3944 - val_mae: 0.4719
# Epoch 46/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6150 - mse: 0.3809 - mae: 0.4669 - val_loss: 0.6276 - val_mse: 0.3973 - val_mae: 0.4716
# Epoch 47/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6150 - mse: 0.3810 - mae: 0.4666 - val_loss: 0.6236 - val_mse: 0.3922 - val_mae: 0.4710
# Epoch 48/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6140 - mse: 0.3796 - mae: 0.4659 - val_loss: 0.6243 - val_mse: 0.3932 - val_mae: 0.4702
# Epoch 49/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6135 - mse: 0.3791 - mae: 0.4659 - val_loss: 0.6238 - val_mse: 0.3925 - val_mae: 0.4701
# Epoch 50/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6133 - mse: 0.3789 - mae: 0.4653 - val_loss: 0.6249 - val_mse: 0.3937 - val_mae: 0.4708
# Epoch 51/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6123 - mse: 0.3778 - mae: 0.4649 - val_loss: 0.6248 - val_mse: 0.3936 - val_mae: 0.4697
# Epoch 52/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6125 - mse: 0.3777 - mae: 0.4648 - val_loss: 0.6221 - val_mse: 0.3903 - val_mae: 0.4686
# Epoch 53/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6114 - mse: 0.3769 - mae: 0.4644 - val_loss: 0.6219 - val_mse: 0.3902 - val_mae: 0.4688
# Epoch 54/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6114 - mse: 0.3766 - mae: 0.4644 - val_loss: 0.6226 - val_mse: 0.3910 - val_mae: 0.4675
# Epoch 55/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6110 - mse: 0.3762 - mae: 0.4635 - val_loss: 0.6218 - val_mse: 0.3900 - val_mae: 0.4681
# Epoch 56/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6107 - mse: 0.3757 - mae: 0.4633 - val_loss: 0.6223 - val_mse: 0.3906 - val_mae: 0.4684
# Epoch 57/100
# 288/288 [==============================] - 32s 109ms/step - loss: 0.6111 - mse: 0.3764 - mae: 0.4637 - val_loss: 0.6239 - val_mse: 0.3926 - val_mae: 0.4673
# Epoch 58/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6107 - mse: 0.3756 - mae: 0.4632 - val_loss: 0.6207 - val_mse: 0.3885 - val_mae: 0.4679
# Epoch 59/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6099 - mse: 0.3747 - mae: 0.4623 - val_loss: 0.6200 - val_mse: 0.3877 - val_mae: 0.4681
# Epoch 60/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6101 - mse: 0.3751 - mae: 0.4624 - val_loss: 0.6216 - val_mse: 0.3897 - val_mae: 0.4685
# Epoch 61/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6095 - mse: 0.3742 - mae: 0.4623 - val_loss: 0.6221 - val_mse: 0.3902 - val_mae: 0.4685
# Epoch 62/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6095 - mse: 0.3741 - mae: 0.4626 - val_loss: 0.6237 - val_mse: 0.3925 - val_mae: 0.4676
# Epoch 63/100
# 288/288 [==============================] - 32s 110ms/step - loss: 0.6093 - mse: 0.3740 - mae: 0.4621 - val_loss: 0.6194 - val_mse: 0.3867 - val_mae: 0.4681
# Epoch 64/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6077 - mse: 0.3719 - mae: 0.4611 - val_loss: 0.6198 - val_mse: 0.3873 - val_mae: 0.4662
# Epoch 65/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6080 - mse: 0.3726 - mae: 0.4616 - val_loss: 0.6200 - val_mse: 0.3877 - val_mae: 0.4661
# Epoch 66/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6075 - mse: 0.3719 - mae: 0.4608 - val_loss: 0.6219 - val_mse: 0.3900 - val_mae: 0.4665
# Epoch 67/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6091 - mse: 0.3736 - mae: 0.4619 - val_loss: 0.6214 - val_mse: 0.3894 - val_mae: 0.4668
# Epoch 68/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6074 - mse: 0.3719 - mae: 0.4611 - val_loss: 0.6217 - val_mse: 0.3898 - val_mae: 0.4663
# Epoch 69/100
# 288/288 [==============================] - 32s 110ms/step - loss: 0.6074 - mse: 0.3717 - mae: 0.4608 - val_loss: 0.6207 - val_mse: 0.3885 - val_mae: 0.4658
# Epoch 70/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6067 - mse: 0.3707 - mae: 0.4603 - val_loss: 0.6199 - val_mse: 0.3874 - val_mae: 0.4663
# Epoch 71/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6062 - mse: 0.3702 - mae: 0.4597 - val_loss: 0.6202 - val_mse: 0.3880 - val_mae: 0.4655
# Epoch 72/100
# 288/288 [==============================] - 32s 110ms/step - loss: 0.6061 - mse: 0.3704 - mae: 0.4600 - val_loss: 0.6190 - val_mse: 0.3864 - val_mae: 0.4642
# Epoch 73/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6057 - mse: 0.3695 - mae: 0.4591 - val_loss: 0.6181 - val_mse: 0.3851 - val_mae: 0.4667
# Epoch 74/100
# 288/288 [==============================] - 32s 109ms/step - loss: 0.6065 - mse: 0.3705 - mae: 0.4598 - val_loss: 0.6187 - val_mse: 0.3859 - val_mae: 0.4659
# Epoch 75/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6057 - mse: 0.3696 - mae: 0.4595 - val_loss: 0.6193 - val_mse: 0.3867 - val_mae: 0.4672
# Epoch 76/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6061 - mse: 0.3700 - mae: 0.4595 - val_loss: 0.6189 - val_mse: 0.3863 - val_mae: 0.4662
# Epoch 77/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6053 - mse: 0.3690 - mae: 0.4590 - val_loss: 0.6195 - val_mse: 0.3869 - val_mae: 0.4668
# Epoch 78/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6051 - mse: 0.3695 - mae: 0.4596 - val_loss: 0.6177 - val_mse: 0.3846 - val_mae: 0.4650
# Epoch 79/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6055 - mse: 0.3695 - mae: 0.4595 - val_loss: 0.6179 - val_mse: 0.3850 - val_mae: 0.4654
# Epoch 80/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6041 - mse: 0.3683 - mae: 0.4590 - val_loss: 0.6225 - val_mse: 0.3910 - val_mae: 0.4659
# Epoch 81/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6044 - mse: 0.3683 - mae: 0.4586 - val_loss: 0.6192 - val_mse: 0.3865 - val_mae: 0.4665
# Epoch 82/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6045 - mse: 0.3679 - mae: 0.4581 - val_loss: 0.6184 - val_mse: 0.3856 - val_mae: 0.4673
# Epoch 83/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6043 - mse: 0.3680 - mae: 0.4584 - val_loss: 0.6177 - val_mse: 0.3846 - val_mae: 0.4645
# Epoch 84/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6039 - mse: 0.3674 - mae: 0.4578 - val_loss: 0.6178 - val_mse: 0.3846 - val_mae: 0.4649
# Epoch 85/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6032 - mse: 0.3670 - mae: 0.4582 - val_loss: 0.6199 - val_mse: 0.3876 - val_mae: 0.4641
# Epoch 86/100
# 288/288 [==============================] - 32s 109ms/step - loss: 0.6033 - mse: 0.3670 - mae: 0.4575 - val_loss: 0.6184 - val_mse: 0.3854 - val_mae: 0.4639
# Epoch 87/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6030 - mse: 0.3664 - mae: 0.4577 - val_loss: 0.6169 - val_mse: 0.3836 - val_mae: 0.4626
# Epoch 88/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6031 - mse: 0.3663 - mae: 0.4576 - val_loss: 0.6181 - val_mse: 0.3852 - val_mae: 0.4653
# Epoch 89/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6025 - mse: 0.3656 - mae: 0.4570 - val_loss: 0.6180 - val_mse: 0.3854 - val_mae: 0.4637
# Epoch 90/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6024 - mse: 0.3656 - mae: 0.4572 - val_loss: 0.6168 - val_mse: 0.3836 - val_mae: 0.4640
# Epoch 91/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6010 - mse: 0.3641 - mae: 0.4563 - val_loss: 0.6189 - val_mse: 0.3863 - val_mae: 0.4640
# Epoch 92/100
# 288/288 [==============================] - 32s 110ms/step - loss: 0.6022 - mse: 0.3654 - mae: 0.4564 - val_loss: 0.6173 - val_mse: 0.3843 - val_mae: 0.4620
# Epoch 93/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6030 - mse: 0.3659 - mae: 0.4570 - val_loss: 0.6176 - val_mse: 0.3846 - val_mae: 0.4628
# Epoch 94/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6019 - mse: 0.3650 - mae: 0.4566 - val_loss: 0.6167 - val_mse: 0.3838 - val_mae: 0.4624
# Epoch 95/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6003 - mse: 0.3629 - mae: 0.4556 - val_loss: 0.6180 - val_mse: 0.3850 - val_mae: 0.4633
# Epoch 96/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6017 - mse: 0.3649 - mae: 0.4562 - val_loss: 0.6160 - val_mse: 0.3827 - val_mae: 0.4625
# Epoch 97/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6013 - mse: 0.3646 - mae: 0.4556 - val_loss: 0.6161 - val_mse: 0.3827 - val_mae: 0.4646
# Epoch 98/100
# 288/288 [==============================] - 31s 109ms/step - loss: 0.6019 - mse: 0.3650 - mae: 0.4564 - val_loss: 0.6186 - val_mse: 0.3861 - val_mae: 0.4640
# Epoch 99/100
# 288/288 [==============================] - 31s 108ms/step - loss: 0.6009 - mse: 0.3639 - mae: 0.4558 - val_loss: 0.6185 - val_mse: 0.3857 - val_mae: 0.4634
# Epoch 100/100
# 288/288 [==============================] - 32s 112ms/step - loss: 0.6008 - mse: 0.3638 - mae: 0.4554 - val_loss: 0.6180 - val_mse: 0.3853 - val_mae: 0.4627
# Entrenamiento finalizado y modelo guardado
#
# EVALUANDO MODELO
# 2302/2302 [==============================] - 62s 27ms/step - loss: 0.5777 - mse: 0.3502 - mae: 0.4448
# 286/286 [==============================] - 7s 25ms/step - loss: 0.6064 - mse: 0.3853 - mae: 0.4627
# 288/288 [==============================] - 7s 25ms/step - loss: 0.5889 - mse: 0.3635 - mae: 0.4512
# Historial y evalucacion correctamente guardados

# %%
#name_files = f"{n_modelo}e{EPOCHS}b{BATCH_SIZE}_{SCALER}_in{INPUT_SHAPE[0]}-{INPUT_SHAPE[1]}"
